# %% [markdown]
# # Pitroski's F-Score

# %%
# Import necessary libraries 
import numpy as np 
import pandas as pd

# %%
pathfile = 'data//f_score//f_score_data1.txt'

# %%
# Read fscore data
data = pd.read_csv(pathfile, delimiter='|')
data.shape
# Out:
# (144875, 40)

# %%
data.head()
# Out:
#    sa_finance1_cocode  sa_company_name  sa_finance1_year  sa_ann_rep_months  \
# 0                  11  20 MICRONS LTD.          19970331                 12
# 1                  11  20 MICRONS LTD.          19980331                 12
# 2                  11  20 MICRONS LTD.          19990331                 12
# 3                  11  20 MICRONS LTD.          20000331                 12
# 4                  11  20 MICRONS LTD.          20010331                 12
#
#   sa_fs_format  sa_total_income  sa_sales  sa_prior_period_extra_ordi_inc  \
# 0        IGAAP            222.0     219.0                             NaN
# 1        IGAAP            307.0     300.3                             NaN
# 2        IGAAP            306.3     304.9                             NaN
# 3        IGAAP            356.1     354.2                             NaN
# 4        IGAAP            447.1     442.2                             2.1
#
#    sa_prior_period_inc  sa_extra_ordi_inc  ...  sa_total_assets  \
# 0                  NaN                NaN  ...            308.0
# 1                  NaN                NaN  ...            507.9
# 2                  NaN                NaN  ...            592.5
# 3                  NaN                NaN  ...            685.7
# 4                  NaN                2.1  ...            779.4
#
#    sa_non_current_assets  sa_current_assets_incl_st_invest_loans  \
# 0                    NaN                                     NaN
# 1                    NaN                                     NaN
# 2                    NaN                                     NaN
# 3                    NaN                                     NaN
# 4                    NaN                                     NaN
#
#    sa_avg_tot_asset_net_miscexp_now_reval  sa_quick_ratio  sa_current_ratio  \
# 0                                     NaN          0.6919            1.1374
# 1                                  405.90          0.7294            1.2757
# 2                                  545.70          0.8693            1.5777
# 3                                  628.90          1.0581            1.8924
# 4                                  717.75          1.1219            1.9247
#
#   sa_debt_equity  sa_cf_net_frm_op_activity  sa_cf_generated_frm_op  \
# 0         2.0921                        NaN                     NaN
# 1         1.5641                        NaN                     NaN
# 2         1.7361                        NaN                     NaN
# 3         1.1412                        NaN                     NaN
# 4         0.8325                        NaN                     NaN
#
#    sa_cf_proceeds_share_issue
# 0                         NaN
# 1                         NaN
# 2                         NaN
# 3                         NaN
# 4                         NaN
#
# [5 rows x 40 columns]

# %%
data.columns
# Out:
# Index(['sa_finance1_cocode', 'sa_company_name', 'sa_finance1_year',
#        'sa_ann_rep_months', 'sa_fs_format', 'sa_total_income', 'sa_sales',
#        'sa_prior_period_extra_ordi_inc', 'sa_prior_period_inc',
#        'sa_extra_ordi_inc', 'sa_tot_inc_net_of_pe', 'sa_pat', 'sa_pbdita',
#        'sa_pbt', 'sa_pbit_net_of_peoifi', 'sa_pat_net_of_pe',
#        'sa_pat_net_of_pe_pc_tot_inc_net_of_pe', 'sa_total_liabilities',
#        'sa_non_current_liabilities', 'sa_long_term_borrowings',
#        'sa_current_liabilities', 'sa_issued_equity_shares',
#        'sa_issued_pref_shares', 'sa_issued_equity_cap', 'sa_issued_pref_cap',
#        'sa_reduct_equity_cap_amt', 'sa_buyback_amt',
#        'sa_issued_equity_shares_in_lakhs', 'sa_shareholders_funds', 'sa_debt',
#        'sa_total_assets', 'sa_non_current_assets',
#        'sa_current_assets_incl_st_invest_loans',
#        'sa_avg_tot_asset_net_miscexp_now_reval', 'sa_quick_ratio',
#        'sa_current_ratio', 'sa_debt_equity', 'sa_cf_net_frm_op_activity',
#        'sa_cf_generated_frm_op', 'sa_cf_proceeds_share_issue'],
#       dtype='object')

# %%
# Get a list of unique companies
company_list = list(data['sa_company_name'].unique())
print("Number of companies: {}".format(len(company_list)))
# Out:
# Number of companies: 8169

# %%
# Datatypes of each columns
data.dtypes
# Out:
# sa_finance1_cocode                          int64
# sa_company_name                            object
# sa_finance1_year                            int64
# sa_ann_rep_months                           int64
# sa_fs_format                               object
# sa_total_income                           float64
# sa_sales                                  float64
# sa_prior_period_extra_ordi_inc            float64
# sa_prior_period_inc                       float64
# sa_extra_ordi_inc                         float64
# sa_tot_inc_net_of_pe                      float64
# sa_pat                                    float64
# sa_pbdita                                 float64
# sa_pbt                                    float64
# sa_pbit_net_of_peoifi                     float64
# sa_pat_net_of_pe                          float64
# sa_pat_net_of_pe_pc_tot_inc_net_of_pe      object
# sa_total_liabilities                      float64
# sa_non_current_liabilities                float64
# sa_long_term_borrowings                   float64
# sa_current_liabilities                    float64
# sa_issued_equity_shares                   float64
# sa_issued_pref_shares                     float64
# sa_issued_equity_cap                      float64
# sa_issued_pref_cap                        float64
# sa_reduct_equity_cap_amt                  float64
# sa_buyback_amt                            float64
# sa_issued_equity_shares_in_lakhs          float64
# sa_shareholders_funds                     float64
# sa_debt                                   float64
# sa_total_assets                           float64
# sa_non_current_assets                     float64
# sa_current_assets_incl_st_invest_loans    float64
# sa_avg_tot_asset_net_miscexp_now_reval    float64
# sa_quick_ratio                            float64
# sa_current_ratio                          float64
# sa_debt_equity                            float64
# sa_cf_net_frm_op_activity                 float64
# sa_cf_generated_frm_op                    float64
# sa_cf_proceeds_share_issue                float64
# dtype: object

# %% [markdown]
# ## Feature Engineering

# %% [markdown]
# ### Extract year

# %%
data['sa_finance1_year']
# Out:
# 0         19970331
# 1         19980331
# 2         19990331
# 3         20000331
# 4         20010331
#             ...
# 144870    20140331
# 144871    20150331
# 144872    20170331
# 144873    20180331
# 144874    20190331
# Name: sa_finance1_year, Length: 144875, dtype: int64

# %%
def extract_year(val):
    val = str(val)
    year = int(val[:4]) - 1
    return year

def extract_year_stock(val):
    val = str(val)
    year = int(val[:4])
    return year

# %%
data['sa_year'] = data['sa_finance1_year'].apply(extract_year)

# %% [markdown]
# ## Extracting Year on Year Data

# %%
years = list(data['sa_year'].unique())

# %%
# Check how many entries for each year 
def check_year_count(df, year_col):
    years = list(df[year_col].unique())
    
    # Iterate through years
    for year in years: 
        filter_df = df[df[year_col] == year]
        print("Number of entries in year {} are: {}".format(year, filter_df.shape[0]))

# %%
# Unique years for f_score data
check_year_count(data, 'sa_year')
# Out:
# Number of entries in year 1996 are: 4899
# Number of entries in year 1997 are: 4787
# Number of entries in year 1998 are: 4851
# Number of entries in year 1999 are: 4752
# Number of entries in year 2000 are: 4719
# Number of entries in year 2001 are: 5052
# Number of entries in year 2002 are: 5073
# Number of entries in year 2003 are: 5041
# Number of entries in year 2004 are: 5343
# Number of entries in year 2005 are: 5537
# Number of entries in year 2006 are: 5602
# Number of entries in year 2007 are: 5647
# Number of entries in year 2008 are: 5759
# Number of entries in year 2009 are: 5808
# Number of entries in year 2010 are: 5712
# Number of entries in year 2011 are: 5665
# Number of entries in year 2012 are: 5642
# Number of entries in year 2013 are: 5556
# Number of entries in year 2014 are: 5376
# Number of entries in year 2015 are: 5343
# Number of entries in year 2016 are: 5208
# Number of entries in year 2017 are: 5039
# Number of entries in year 2018 are: 4634
# Number of entries in year 1990 are: 1806
# Number of entries in year 1991 are: 2205
# Number of entries in year 1992 are: 2866
# Number of entries in year 1993 are: 3925
# Number of entries in year 1994 are: 5020
# Number of entries in year 1995 are: 5150
# Number of entries in year 1988 are: 1114
# Number of entries in year 1989 are: 1338
# Number of entries in year 1987 are: 406

# %% [markdown]
# We have enough data from year 1994 so we can do a 24 year analysis. Let's check trading data.

# %%
# Collect three year fscore data 
for year in range(1998, 2017):
    mask1 = data['sa_year'] == year
    mask2 = data['sa_year'] == year+1
    mask3 = data['sa_year'] == year+2
    
    year_data = data[(mask1) | (mask2) | (mask3)]
    filepath = 'fscore_data_' + str(year) + '-' + str(year+2) + '.csv'
    year_data.to_csv(filepath, index=False)
    print(f"Year {year_data['sa_year'].unique()} data saved")
# Out:
# Year [1998 1999 2000] data saved
# Year [1999 2000 2001] data saved
# Year [2000 2001 2002] data saved
# Year [2001 2002 2003] data saved
# Year [2002 2003 2004] data saved
# Year [2003 2004 2005] data saved
# Year [2004 2005 2006] data saved
# Year [2005 2006 2007] data saved
# Year [2006 2007 2008] data saved
# Year [2007 2008 2009] data saved
# Year [2008 2009 2010] data saved
# Year [2009 2010 2011] data saved
# Year [2010 2011 2012] data saved
# Year [2011 2012 2013] data saved
# Year [2012 2013 2014] data saved
# Year [2013 2014 2015] data saved
# Year [2014 2015 2016] data saved
# Year [2015 2016 2017] data saved
# Year [2016 2017 2018] data saved

# %%
year_data['sa_year'].unique()
# Out:
# array([2018], dtype=int64)

# %%
# %%time
# Read in trading data 
trade_data = pd.read_csv('data//trading_data//trading_data.txt', delimiter='|')
print(trade_data.shape)
# Out:
# (12943055, 9)
# Wall time: 21.1 s

# %%
trade_data.head()
# Out:
#    co_code     company_name  co_stkdate  bse_closing_price  bse_market_cap  \
# 0       11  20 MICRONS LTD.    20081006              33.30        470.2100
# 1       11  20 MICRONS LTD.    20081007              30.40        429.2607
# 2       11  20 MICRONS LTD.    20081008              26.35        372.0730
# 3       11  20 MICRONS LTD.    20081010              23.35        329.7118
# 4       11  20 MICRONS LTD.    20081013              24.90        351.5984
#
#    bse_pb  nse_closing_price  nse_market_cap  nse_pb
# 0  1.1619              33.65        475.1521  1.1741
# 1  1.0607              30.10        425.0246  1.0502
# 2  0.9194              26.50        374.1911  0.9246
# 3  0.8147              23.20        327.5937  0.8095
# 4  0.8688              24.65        348.0683  0.8601

# %%
# %%time
# Add years column
trade_data['year'] = trade_data['co_stkdate'].apply(extract_year_stock)
trade_data.head()
# Out:
# Wall time: 18.3 s

# %%
trade_data.isnull().sum()
# Out:
# co_code                    0
# company_name               0
# co_stkdate                 0
# bse_closing_price     333490
# bse_market_cap        334318
# bse_pb               1360952
# nse_closing_price    6816736
# nse_market_cap       6817157
# nse_pb               7182381
# year                       0
# dtype: int64

# %% [markdown]
# So, we only have data from 2000 so we can only analyse that stuff. Divide the trading data year on year.

# %%
data2000 = trade_data[trade_data['year'] == 2004]
data2000.shape
# Out:
# (531969, 10)

# %%
data2000
# Out:
#           co_code             company_name  co_stkdate  bse_closing_price  \
# 3387          289         A B C INDIA LTD.    20040101              12.55
# 3388          289         A B C INDIA LTD.    20040102              13.80
# 3389          289         A B C INDIA LTD.    20040105              15.18
# 3390          289         A B C INDIA LTD.    20040106              16.69
# 3391          289         A B C INDIA LTD.    20040107              17.43
# ...           ...                      ...         ...                ...
# 12556734   380893  SMARTLINK HOLDINGS LTD.    20041227             121.40
# 12556735   380893  SMARTLINK HOLDINGS LTD.    20041228             120.95
# 12556736   380893  SMARTLINK HOLDINGS LTD.    20041229             118.75
# 12556737   380893  SMARTLINK HOLDINGS LTD.    20041230             118.85
# 12556738   380893  SMARTLINK HOLDINGS LTD.    20041231             119.50
#
#           bse_market_cap  bse_pb  nse_closing_price  nse_market_cap  nse_pb  \
# 3387             62.7796  0.2207                NaN             NaN     NaN
# 3388             69.0326  0.2427                NaN             NaN     NaN
# 3389             75.9359  0.2670                NaN             NaN     NaN
# 3390             83.4894  0.2936                NaN             NaN     NaN
# 3391             87.1912  0.3066                NaN             NaN     NaN
# ...                  ...     ...                ...             ...     ...
# 12556734       3642.5888  2.4237             121.50       3645.5893  2.4257
# 12556735       3629.0866  2.4147             121.35       3641.0885  2.4227
# 12556736       3563.0759  2.3708             119.00       3570.5771  2.3758
# 12556737       3566.0764  2.3728             119.40       3582.5791  2.3838
# 12556738       3585.5796  2.2845             119.25       3578.0784  2.2798
#
#           year
# 3387      2004
# 3388      2004
# 3389      2004
# 3390      2004
# 3391      2004
# ...        ...
# 12556734  2004
# 12556735  2004
# 12556736  2004
# 12556737  2004
# 12556738  2004
#
# [531969 rows x 10 columns]

# %%
# data2000.to_csv('year_on_year_data//trading_data2004.csv', index=False)

# %%
# # Save Yearly data 
# for year in range(2005, 2021):
#     year_data = trade_data[trade_data['year'] == year]
#     filepath = 'year_on_year_data//trading_data'+ str(year) + '.csv'
#     year_data.to_csv(filepath, index=False)
#     print(f"The size of the data is {year_data.shape}")
#     print(f"Year {year} data saved")
# Out:
# year_on_year_data//trading_data2005.csv
# The size of the data is (635942, 10)
# Year 2005 data saved
# year_on_year_data//trading_data2006.csv
# The size of the data is (639010, 10)
# Year 2006 data saved
# year_on_year_data//trading_data2007.csv
# The size of the data is (677845, 10)
# Year 2007 data saved
# year_on_year_data//trading_data2008.csv
# The size of the data is (666865, 10)
# Year 2008 data saved
# year_on_year_data//trading_data2009.csv
# The size of the data is (664697, 10)
# Year 2009 data saved
# year_on_year_data//trading_data2010.csv
# The size of the data is (759226, 10)
# Year 2010 data saved
# year_on_year_data//trading_data2011.csv
# The size of the data is (731210, 10)
# Year 2011 data saved
# year_on_year_data//trading_data2012.csv
# The size of the data is (741981, 10)
# Year 2012 data saved
# year_on_year_data//trading_data2013.csv
# The size of the data is (662697, 10)
# Year 2013 data saved
# year_on_year_data//trading_data2014.csv
# The size of the data is (731965, 10)
# Year 2014 data saved
# year_on_year_data//trading_data2015.csv
# The size of the data is (724366, 10)
# Year 2015 data saved
# year_on_year_data//trading_data2016.csv
# The size of the data is (705841, 10)
# Year 2016 data saved
# year_on_year_data//trading_data2017.csv
# The size of the data is (728839, 10)
# Year 2017 data saved
# year_on_year_data//trading_data2018.csv
# The size of the data is (723549, 10)
# Year 2018 data saved
# year_on_year_data//trading_data2019.csv
# The size of the data is (696820, 10)
# Year 2019 data saved
# year_on_year_data//trading_data2020.csv
# The size of the data is (177906, 10)
# Year 2020 data saved

# %%
# unique years for trading data
check_year_count(trade_data, 'year')
# Out:
# Number of entries in year 2008 are: 666865
# Number of entries in year 2009 are: 664697
# Number of entries in year 2010 are: 759226
# Number of entries in year 2011 are: 731210
# Number of entries in year 2012 are: 741981
# Number of entries in year 2013 are: 662697
# Number of entries in year 2014 are: 731965
# Number of entries in year 2015 are: 724366
# Number of entries in year 2016 are: 705841
# Number of entries in year 2017 are: 728839
# Number of entries in year 2018 are: 723549
# Number of entries in year 2019 are: 696820
# Number of entries in year 2020 are: 177906
# Number of entries in year 2000 are: 475907
# Number of entries in year 2001 are: 366073
# Number of entries in year 2002 are: 424781
# Number of entries in year 2003 are: 475566
# Number of entries in year 2004 are: 531969
# Number of entries in year 2005 are: 635942
# Number of entries in year 2006 are: 639010
# Number of entries in year 2007 are: 677845

# %%
d = pd.read_csv('trading_data2000.csv', nrows=100)
d.head()
# Out:
#    co_code      company_name  co_stkdate  bse_closing_price  bse_market_cap  \
# 0      289  A B C INDIA LTD.    20000103                7.3         36.5172
# 1      289  A B C INDIA LTD.    20000104                7.4         37.0175
# 2      289  A B C INDIA LTD.    20000105                7.0         35.0165
# 3      289  A B C INDIA LTD.    20000106                7.4         37.0175
# 4      289  A B C INDIA LTD.    20000107                7.5         37.5177
#
#    bse_pb  nse_closing_price  nse_market_cap  nse_pb  year
# 0  0.1184                NaN             NaN     NaN  2000
# 1  0.1200                NaN             NaN     NaN  2000
# 2  0.1135                NaN             NaN     NaN  2000
# 3  0.1200                NaN             NaN     NaN  2000
# 4  0.1217                NaN             NaN     NaN  2000

# %% [markdown]
# ### Check Merge hits

# %%
data2000.head()
# Out:
#       co_code      company_name co_stkdate  bse_closing_price  bse_market_cap  \
# 2841      289  A B C INDIA LTD.   20000103                7.3         36.5172
# 2842      289  A B C INDIA LTD.   20000104                7.4         37.0175
# 2843      289  A B C INDIA LTD.   20000105                7.0         35.0165
# 2844      289  A B C INDIA LTD.   20000106                7.4         37.0175
# 2845      289  A B C INDIA LTD.   20000107                7.5         37.5177
#
#       bse_pb  nse_closing_price  nse_market_cap  nse_pb  year
# 2841  0.1184                NaN             NaN     NaN  2000
# 2842  0.1200                NaN             NaN     NaN  2000
# 2843  0.1135                NaN             NaN     NaN  2000
# 2844  0.1200                NaN             NaN     NaN  2000
# 2845  0.1217                NaN             NaN     NaN  2000

# %%
data2000['co_stkdate'] = data2000['co_stkdate'].astype(str)
data2000['key'] = data2000['company_name'] + data2000['co_stkdate']
data2000.head()
# Out:
# c:\users\hp\appdata\local\programs\python\python36\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.
# c:\users\hp\appdata\local\programs\python\python36\lib\site-packages\ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#       co_code      company_name co_stkdate  bse_closing_price  bse_market_cap  \
# 2841      289  A B C INDIA LTD.   20000103                7.3         36.5172
# 2842      289  A B C INDIA LTD.   20000104                7.4         37.0175
# 2843      289  A B C INDIA LTD.   20000105                7.0         35.0165
# 2844      289  A B C INDIA LTD.   20000106                7.4         37.0175
# 2845      289  A B C INDIA LTD.   20000107                7.5         37.5177
#
#       bse_pb  nse_closing_price  nse_market_cap  nse_pb  year  \
# 2841  0.1184                NaN             NaN     NaN  2000
# 2842  0.1200                NaN             NaN     NaN  2000
# 2843  0.1135                NaN             NaN     NaN  2000
# 2844  0.1200                NaN             NaN     NaN  2000
# 2845  0.1217                NaN             NaN     NaN  2000
#
#                            key
# 2841  A B C INDIA LTD.20000103
# 2842  A B C INDIA LTD.20000104
# 2843  A B C INDIA LTD.20000105
# 2844  A B C INDIA LTD.20000106
# 2845  A B C INDIA LTD.20000107

# %%
data.head()
# Out:
#    sa_finance1_cocode  sa_company_name sa_finance1_year  sa_ann_rep_months  \
# 0                  11  20 MICRONS LTD.         19970331                 12
# 1                  11  20 MICRONS LTD.         19980331                 12
# 2                  11  20 MICRONS LTD.         19990331                 12
# 3                  11  20 MICRONS LTD.         20000331                 12
# 4                  11  20 MICRONS LTD.         20010331                 12
#
#   sa_fs_format  sa_total_income  sa_sales  sa_prior_period_extra_ordi_inc  \
# 0        IGAAP            222.0     219.0                             NaN
# 1        IGAAP            307.0     300.3                             NaN
# 2        IGAAP            306.3     304.9                             NaN
# 3        IGAAP            356.1     354.2                             NaN
# 4        IGAAP            447.1     442.2                             2.1
#
#    sa_prior_period_inc  sa_extra_ordi_inc  ...  sa_non_current_assets  \
# 0                  NaN                NaN  ...                    NaN
# 1                  NaN                NaN  ...                    NaN
# 2                  NaN                NaN  ...                    NaN
# 3                  NaN                NaN  ...                    NaN
# 4                  NaN                2.1  ...                    NaN
#
#    sa_current_assets_incl_st_invest_loans  \
# 0                                     NaN
# 1                                     NaN
# 2                                     NaN
# 3                                     NaN
# 4                                     NaN
#
#    sa_avg_tot_asset_net_miscexp_now_reval  sa_quick_ratio  sa_current_ratio  \
# 0                                     NaN          0.6919            1.1374
# 1                                  405.90          0.7294            1.2757
# 2                                  545.70          0.8693            1.5777
# 3                                  628.90          1.0581            1.8924
# 4                                  717.75          1.1219            1.9247
#
#    sa_debt_equity sa_cf_net_frm_op_activity  sa_cf_generated_frm_op  \
# 0          2.0921                       NaN                     NaN
# 1          1.5641                       NaN                     NaN
# 2          1.7361                       NaN                     NaN
# 3          1.1412                       NaN                     NaN
# 4          0.8325                       NaN                     NaN
#
#    sa_cf_proceeds_share_issue                      key
# 0                         NaN  20 MICRONS LTD.19970331
# 1                         NaN  20 MICRONS LTD.19980331
# 2                         NaN  20 MICRONS LTD.19990331
# 3                         NaN  20 MICRONS LTD.20000331
# 4                         NaN  20 MICRONS LTD.20010331
#
# [5 rows x 41 columns]

# %%
data['sa_finance1_year'] = data['sa_finance1_year'].astype(str)
data['key'] = data['sa_company_name'] + data['sa_finance1_year']
data.head()
# Out:
#    sa_finance1_cocode  sa_company_name sa_finance1_year  sa_ann_rep_months  \
# 0                  11  20 MICRONS LTD.         19970331                 12
# 1                  11  20 MICRONS LTD.         19980331                 12
# 2                  11  20 MICRONS LTD.         19990331                 12
# 3                  11  20 MICRONS LTD.         20000331                 12
# 4                  11  20 MICRONS LTD.         20010331                 12
#
#   sa_fs_format  sa_total_income  sa_sales  sa_prior_period_extra_ordi_inc  \
# 0        IGAAP            222.0     219.0                             NaN
# 1        IGAAP            307.0     300.3                             NaN
# 2        IGAAP            306.3     304.9                             NaN
# 3        IGAAP            356.1     354.2                             NaN
# 4        IGAAP            447.1     442.2                             2.1
#
#    sa_prior_period_inc  sa_extra_ordi_inc  ...  sa_non_current_assets  \
# 0                  NaN                NaN  ...                    NaN
# 1                  NaN                NaN  ...                    NaN
# 2                  NaN                NaN  ...                    NaN
# 3                  NaN                NaN  ...                    NaN
# 4                  NaN                2.1  ...                    NaN
#
#    sa_current_assets_incl_st_invest_loans  \
# 0                                     NaN
# 1                                     NaN
# 2                                     NaN
# 3                                     NaN
# 4                                     NaN
#
#    sa_avg_tot_asset_net_miscexp_now_reval  sa_quick_ratio  sa_current_ratio  \
# 0                                     NaN          0.6919            1.1374
# 1                                  405.90          0.7294            1.2757
# 2                                  545.70          0.8693            1.5777
# 3                                  628.90          1.0581            1.8924
# 4                                  717.75          1.1219            1.9247
#
#    sa_debt_equity sa_cf_net_frm_op_activity  sa_cf_generated_frm_op  \
# 0          2.0921                       NaN                     NaN
# 1          1.5641                       NaN                     NaN
# 2          1.7361                       NaN                     NaN
# 3          1.1412                       NaN                     NaN
# 4          0.8325                       NaN                     NaN
#
#    sa_cf_proceeds_share_issue                      key
# 0                         NaN  20 MICRONS LTD.19970331
# 1                         NaN  20 MICRONS LTD.19980331
# 2                         NaN  20 MICRONS LTD.19990331
# 3                         NaN  20 MICRONS LTD.20000331
# 4                         NaN  20 MICRONS LTD.20010331
#
# [5 rows x 41 columns]

# %%
len(list(data[data['sa_year'] == 2000]['sa_finance1_cocode'].unique()))
# Out:
# 4705

# %%
# Merge Data 
merged = pd.merge(data, data2000, how='inner', on='key' )
merged.shape
# Out:
# (1886, 52)

# %%
merged.head()
# Out:
#    sa_finance1_cocode            sa_company_name sa_finance1_year  \
# 0                 289           A B C INDIA LTD.         20000331
# 1                 363   STARLOG ENTERPRISES LTD.         20000331
# 2                 666         A C I INFOCOM LTD.         20000331
# 3                 783           A D F FOODS LTD.         20000331
# 4                 934  APEEJAY TEA LTD. [MERGED]         20000331
#
#    sa_ann_rep_months sa_fs_format  sa_total_income  sa_sales  \
# 0                 12        IGAAP           1106.1    1086.0
# 1                 12        IGAAP            696.8     647.7
# 2                 12        IGAAP            239.4     236.9
# 3                 12        IGAAP            391.3     388.1
# 4                 12        IGAAP           1025.2     959.2
#
#    sa_prior_period_extra_ordi_inc  sa_prior_period_inc  sa_extra_ordi_inc  \
# 0                             1.2                  1.1                0.1
# 1                             0.8                  NaN                0.8
# 2                             0.1                  0.1                NaN
# 3                             0.4                  0.4                NaN
# 4                             1.8                  1.8                NaN
#
#    ...  co_code               company_name  co_stkdate  bse_closing_price  \
# 0  ...      289           A B C INDIA LTD.    20000331               6.75
# 1  ...      363   STARLOG ENTERPRISES LTD.    20000331              20.00
# 2  ...      666         A C I INFOCOM LTD.    20000331              38.75
# 3  ...      783           A D F FOODS LTD.    20000331               5.95
# 4  ...      934  APEEJAY TEA LTD. [MERGED]    20000331              90.00
#
#    bse_market_cap  bse_pb nse_closing_price  nse_market_cap  nse_pb  year
# 0         33.7659  0.1132               NaN             NaN     NaN  2000
# 1        226.4040  0.2536             20.55        232.6301  0.2606  2000
# 2        170.5306  2.3297               NaN             NaN     NaN  2000
# 3         59.6392  0.2847              6.85         68.6603  0.3277  2000
# 4        540.0000  0.6645               NaN             NaN     NaN  2000
#
# [5 rows x 52 columns]

# %%
len(list(merged['sa_finance1_cocode'].unique()))
# Out:
# 1885

# %% [markdown]
# Collect 1999-2000 Fscore data

# %%
fscore2000 = data[(data['sa_year'] == 1999) | (data['sa_year'] == 2000) | (data['sa_year'] == 1998)]
fscore2000.shape
# Out:
# (14322, 41)

# %%
fscore2000.to_csv('fscore_data_1998-2000.csv', index=False)

# %% [markdown]
# ## F-Scores

# %% [markdown]
# ### F_ROA ( return on assets )

# %% [markdown]
# Formula = Net Income after Extraordinary items / Total Assets at the beginning of the year

# %%
def del_roa(data):
    print("Dropping null values...")
    
    # remove null values
    print("Rows before dropping: {}".format(data.shape[0]))
    data.dropna(subset=['sa_total_assets'], inplace=True)
    print("Rows after dropping: {}".format(data.shape[0]))
    
    # Create beginning of year assets column 
    data['sa_begin_year_total_assets'] = data['sa_t']

# %%
data['sa_total_assets']
# Out:
# 0         308.0
# 1         507.9
# 2         592.5
# 3         685.7
# 4         779.4
#           ...
# 144870     61.4
# 144871     73.9
# 144872     79.4
# 144873     76.5
# 144874     87.0
# Name: sa_total_assets, Length: 144875, dtype: float64

# %%
# Check for null values 
data[data['sa_total_assets'].isnull()]
# Out:
#         sa_finance1_cocode                      sa_company_name  \
# 1300                  4210                ABACUS COMPUTERS LTD.
# 1301                  4210                ABACUS COMPUTERS LTD.
# 3293                  8645          AIRCOMMAND AIRTECHNICS LTD.
# 3311                  8646                AIRCOMMAND INDIA LTD.
# 4413                 11443             ALLSEC TECHNOLOGIES LTD.
# ...                    ...                                  ...
# 144047              560528              PRAXIS HOME RETAIL LTD.
# 144465              580641            DEBOCK SALES & MKTG. LTD.
# 144466              580641            DEBOCK SALES & MKTG. LTD.
# 144467              580641            DEBOCK SALES & MKTG. LTD.
# 144577              582585  SPACE INCUBATRICS TECHNOLOGIES LTD.
#
#         sa_finance1_year  sa_ann_rep_months sa_fs_format  sa_total_income  \
# 1300            20110331                 12        IGAAP              0.6
# 1301            20120331                 12        IGAAP              NaN
# 3293            20130630                 15        IGAAP              0.2
# 3311            20140331                  9        IGAAP              0.1
# 4413            19990930                 13        IGAAP              NaN
# ...                  ...                ...          ...              ...
# 144047          20160331                 12        IGAAP              NaN
# 144465          20090331                  8        IGAAP              NaN
# 144466          20100331                 12        IGAAP              NaN
# 144467          20110331                 12        IGAAP              NaN
# 144577          20170331                 12        IGAAP              NaN
#
#         sa_sales  sa_prior_period_extra_ordi_inc  sa_prior_period_inc  \
# 1300         NaN                             0.6                  NaN
# 1301         NaN                             NaN                  NaN
# 3293         0.2                             NaN                  NaN
# 3311         0.1                             NaN                  NaN
# 4413         NaN                             NaN                  NaN
# ...          ...                             ...                  ...
# 144047       NaN                             NaN                  NaN
# 144465       NaN                             NaN                  NaN
# 144466       NaN                             NaN                  NaN
# 144467       NaN                             NaN                  NaN
# 144577       NaN                             NaN                  NaN
#
#         sa_extra_ordi_inc  ...  sa_non_current_assets  \
# 1300                  0.6  ...                    NaN
# 1301                  0.0  ...                    NaN
# 3293                  0.0  ...                    NaN
# 3311                  0.0  ...                    NaN
# 4413                  0.0  ...                    NaN
# ...                   ...  ...                    ...
# 144047                0.0  ...                    NaN
# 144465                0.0  ...                    NaN
# 144466                0.0  ...                    NaN
# 144467                0.0  ...                    NaN
# 144577                0.0  ...                    NaN
#
#         sa_current_assets_incl_st_invest_loans  \
# 1300                                       NaN
# 1301                                       NaN
# 3293                                       NaN
# 3311                                       NaN
# 4413                                       NaN
# ...                                        ...
# 144047                                     NaN
# 144465                                     NaN
# 144466                                     NaN
# 144467                                     NaN
# 144577                                     NaN
#
#         sa_avg_tot_asset_net_miscexp_now_reval  sa_quick_ratio  \
# 1300                                      0.05             NaN
# 1301                                      0.00             NaN
# 3293                                      0.05             NaN
# 3311                                      0.70             NaN
# 4413                                      0.00             NaN
# ...                                        ...             ...
# 144047                                    0.00             0.0
# 144465                                     NaN             NaN
# 144466                                    0.00             NaN
# 144467                                    0.00             NaN
# 144577                                     NaN             NaN
#
#         sa_current_ratio  sa_debt_equity sa_cf_net_frm_op_activity  \
# 1300                 NaN             NaN                       NaN
# 1301                 NaN             NaN                       NaN
# 3293                 NaN             NaN                       NaN
# 3311                 NaN             NaN                       NaN
# 4413                 NaN             NaN                       NaN
# ...                  ...             ...                       ...
# 144047               0.0             NaN                       NaN
# 144465               NaN             NaN                       NaN
# 144466               NaN             NaN                       NaN
# 144467               NaN             NaN                       NaN
# 144577               NaN             NaN                       NaN
#
#         sa_cf_generated_frm_op  sa_cf_proceeds_share_issue  sa_year
# 1300                       NaN                         NaN     2011
# 1301                       NaN                         NaN     2012
# 3293                       NaN                         NaN     2013
# 3311                       NaN                         NaN     2014
# 4413                       NaN                         NaN     1999
# ...                        ...                         ...      ...
# 144047                     NaN                         NaN     2016
# 144465                     NaN                         NaN     2009
# 144466                     NaN                         NaN     2010
# 144467                     NaN                         NaN     2011
# 144577                     NaN                         NaN     2017
#
# [299 rows x 41 columns]

# %% [markdown]
# There are certain null value in asset data. For now, I will be removing them.

# %%
print("Rows before dropping: {}".format(data.shape[0]))
data.dropna(subset=['sa_total_assets'], inplace=True)
print("Rows after dropping: {}".format(data.shape[0]))
# Out:
# Rows before dropping: 144875
# Rows after dropping: 144576

# %%
# Create beginning of year assets column 
data['sa_begin_year_total_assets'] =

# %%
# Fill Extra Ordinary Income
data['sa_extra_ordi_inc'].fillna(0, inplace=True)
data['sa_tot_inc_net_of_pe'].fillna(0, inplace=True)

# %%
fscore2000.drop(['key'], inplace=True, axis=1)
# Out:
# c:\users\hp\appdata\local\programs\python\python36\lib\site-packages\pandas\core\frame.py:3997: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   errors=errors,

# %%
fscore2000.columns
# Out:
# Index(['sa_finance1_cocode', 'sa_company_name', 'sa_finance1_year',
#        'sa_ann_rep_months', 'sa_fs_format', 'sa_total_income', 'sa_sales',
#        'sa_prior_period_extra_ordi_inc', 'sa_prior_period_inc',
#        'sa_extra_ordi_inc', 'sa_tot_inc_net_of_pe', 'sa_pat', 'sa_pbdita',
#        'sa_pbt', 'sa_pbit_net_of_peoifi', 'sa_pat_net_of_pe',
#        'sa_pat_net_of_pe_pc_tot_inc_net_of_pe', 'sa_total_liabilities',
#        'sa_non_current_liabilities', 'sa_long_term_borrowings',
#        'sa_current_liabilities', 'sa_issued_equity_shares',
#        'sa_issued_pref_shares', 'sa_issued_equity_cap', 'sa_issued_pref_cap',
#        'sa_reduct_equity_cap_amt', 'sa_buyback_amt',
#        'sa_issued_equity_shares_in_lakhs', 'sa_shareholders_funds', 'sa_debt',
#        'sa_total_assets', 'sa_non_current_assets',
#        'sa_current_assets_incl_st_invest_loans',
#        'sa_avg_tot_asset_net_miscexp_now_reval', 'sa_quick_ratio',
#        'sa_current_ratio', 'sa_debt_equity', 'sa_cf_net_frm_op_activity',
#        'sa_cf_generated_frm_op', 'sa_cf_proceeds_share_issue', 'sa_year'],
#       dtype='object')
